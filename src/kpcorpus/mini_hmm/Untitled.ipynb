# %%
#/usr/bin/env python
from hmm_with_mini_relmin import HMM
from kp_data_loader import KPDataLoader
from sklearn.cross_validation import KFold
import logging
import sys

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
ch = logging.StreamHandler(sys.stdout)
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# -----------------------------------------------

loader = KPDataLoader()
for i in range(1,46):
    loader.load_file('ex{0}a.mid.csv'.format(i))
XX, Y = loader.get_XX_and_Y()

# -----------------------------------------------

n = len(XX)
j = int(n - (float(n) * 0.5))

XX_train = XX[0:j]
Y_train = Y[0:j]

XX_test = XX[j:n]
Y_test = Y[j:n]

# -----------------------------------------------

model = HMM()
model.train(XX_train, Y_train)
accuracy, y_pred = model.test(XX_test, Y_test)

logger.info("Accuracy: {0}".format(accuracy))

# -----------------------------------------------

loader = KPDataLoader()
for i in range(1,46):
    loader.load_file('ex{0}a.mid.csv'.format(i))
XX, Y = loader.get_XX_and_Y()

# -----------------------------------------------

n = len(XX)
j = int(n - (float(n) * 0.5))

XX_train = XX[0:j]
Y_train = Y[0:j]

XX_test = XX[j:n]
Y_test = Y[j:n]

def cross_val(n=10):
		"""
		n : n-crossvalidation
		"""

		L = len(XX_train)
		kf = KFold(L,n_folds=n)

		models = []
		scores = []

		c = 0

		for c, (train_indexes, val_indexes) in enumerate(kf):

			logger.debug("On Fold " + str(c))

			xx_train = []
			y_train = []
			xx_val = []
			y_val = []
			for i in train_indexes:
				xx_train.append(XX_train[i][:])
				y_train.append(Y_train[i][:])
			for j in val_indexes:
				xx_val.append(XX_train[j][:])
				y_val.append(Y_train[j][:])

			model = HMM()

			logger.debug(str(len(xx_train)) + "," + str(len(y_train)))
			model.train(xx_train,y_train)

			logger.debug("Testing ...")
			score, _ = model.test(xx_val,y_val)

			logger.debug("Fold " + str(c) + " scored " + str(score))

			models.append(model)
			scores.append(score)

		max_score = max(scores)

		print max_score

		max_index = 0
		for idx, score in enumerate(scores):
			if score == max_score:
				max_index = idx
				break

		logger.info("Final Test ...")

		score, _ = models[max_index].test(XX_test,Y_test)
		logger.info("Final Accuracy: {0}".format(score))

		return models[max_index]

model = cross_val(10)
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Accuracy: 0.204592901879
# Accuracy: 0.204592901879
# On Fold 0
# On Fold 0
# 19,19
# 19,19
# Testing ...
# Testing ...
# Fold 0 scored 0.271844660194
# Fold 0 scored 0.271844660194
# On Fold 1
# On Fold 1
# 19,19
# 19,19
# Testing ...
# Testing ...
# Fold 1 scored 0.260869565217
# Fold 1 scored 0.260869565217
# On Fold 2
# On Fold 2
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 2 scored 0.142857142857
# Fold 2 scored 0.142857142857
# On Fold 3
# On Fold 3
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 3 scored 0.333333333333
# Fold 3 scored 0.333333333333
# On Fold 4
# On Fold 4
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 4 scored 0.254237288136
# Fold 4 scored 0.254237288136
# On Fold 5
# On Fold 5
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 5 scored 0.285714285714
# Fold 5 scored 0.285714285714
# On Fold 6
# On Fold 6
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 6 scored 0.230769230769
# Fold 6 scored 0.230769230769
# On Fold 7
# On Fold 7
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 7 scored 0.185185185185
# Fold 7 scored 0.185185185185
# On Fold 8
# On Fold 8
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 8 scored 0.142857142857
# Fold 8 scored 0.142857142857
# On Fold 9
# On Fold 9
# 20,20
# 20,20
# Testing ...
# Testing ...
# Fold 9 scored 0.193548387097
# Fold 9 scored 0.193548387097
# 0.333333333333
# Final Test ...
# Final Test ...
# Final Accuracy: 0.200417536534
# Final Accuracy: 0.200417536534
